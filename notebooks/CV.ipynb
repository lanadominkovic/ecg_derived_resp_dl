# %%
import scipy.signal as signal
from sklearn.model_selection import KFold, train_test_split
import tensorflow as tf
from tensorflow import keras
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, LambdaCallback
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import pandas as pd
import random

import os
import numpy as np
from scipy import signal

from keras import layers, models, regularizers

from tensorflow.keras import layers, models, regularizers

def create_model(config):
    kernel_size = config.kernel_size
    regularizer = regularizers.l2(config.reg)
    dropout_rate = config.dropout
    size_0 = config.start_filters

    # Input layer
    in_data = layers.Input(shape=(config.input_size, 1))

    # Encoder part
    conv0 = layers.Conv1D(size_0, kernel_size, kernel_regularizer=regularizer, activation='relu', padding='same', kernel_initializer='he_normal')(in_data)
    conv0 = layers.BatchNormalization()(conv0)
    conv0 = layers.Conv1D(size_0, kernel_size, kernel_regularizer=regularizer, activation='relu', padding='same', kernel_initializer='he_normal')(conv0)
    conv0 = layers.BatchNormalization()(conv0)
    pool0 = layers.MaxPooling1D(pool_size=2)(conv0)

    size_1 = size_0 * 2
    conv1 = layers.Conv1D(size_1, kernel_size, kernel_regularizer=regularizer, activation='relu', padding='same', kernel_initializer='he_normal')(pool0)
    conv1 = layers.BatchNormalization()(conv1)
    conv1 = layers.Conv1D(size_1, kernel_size, kernel_regularizer=regularizer, activation='relu', padding='same', kernel_initializer='he_normal')(conv1)
    conv1 = layers.BatchNormalization()(conv1)
    conv1 = layers.Dropout(dropout_rate)(conv1)
    pool1 = layers.MaxPooling1D(pool_size=2)(conv1)

    size_2 = size_1 * 2
    conv2 = layers.Conv1D(size_2, kernel_size, kernel_regularizer=regularizer, activation='relu', padding='same', kernel_initializer='he_normal')(pool1)
    conv2 = layers.BatchNormalization()(conv2)
    conv2 = layers.Conv1D(size_2, kernel_size, kernel_regularizer=regularizer, activation='relu', padding='same', kernel_initializer='he_normal')(conv2)
    conv2 = layers.BatchNormalization()(conv2)

    # Decoder part
    up1 = layers.UpSampling1D(size=2)(conv2)
    up_conv1 = layers.Conv1D(size_2, 2, activation='relu', padding='same', kernel_initializer='he_normal')(up1)
    up_conv1 = layers.BatchNormalization()(up_conv1)
    merge1 = layers.concatenate([conv1, up_conv1], axis=2)
    conv3 = layers.Conv1D(size_1, kernel_size, kernel_regularizer=regularizer, activation='relu', padding='same', kernel_initializer='he_normal')(merge1)
    conv3 = layers.BatchNormalization()(conv3)
    conv3 = layers.Conv1D(size_1, kernel_size, kernel_regularizer=regularizer, activation='relu', padding='same', kernel_initializer='he_normal')(conv3)
    conv3 = layers.BatchNormalization()(conv3)
    conv3 = layers.Dropout(dropout_rate)(conv3)

    up2 = layers.UpSampling1D(size=2)(conv3)
    up_conv2 = layers.Conv1D(size_1, 2, activation='relu', padding='same', kernel_initializer='he_normal')(up2)
    up_conv2 = layers.BatchNormalization()(up_conv2)
    merge2 = layers.concatenate([conv0, up_conv2], axis=2)
    conv4 = layers.Conv1D(size_0, kernel_size, kernel_regularizer=regularizer, activation='relu', padding='same', kernel_initializer='he_normal')(merge2)
    conv4 = layers.BatchNormalization()(conv4)
    conv4 = layers.Conv1D(size_0, kernel_size, kernel_regularizer=regularizer, activation='relu', padding='same', kernel_initializer='he_normal')(conv4)
    conv4 = layers.BatchNormalization()(conv4)

    # Output layer
    out_data = layers.Conv1D(1, kernel_size, activation='sigmoid', padding='same')(conv4)

    model = models.Model(inputs=[in_data], outputs=[out_data])
    model.summary()

    return model


def sliding_window(data, window_size, downsampled_window_size, overlap, train_patients, validation_patients, test_patients):
    windows_ecg_train = []
    windows_resp_train = []

    for train_patient in train_patients:
    
        N = len(data[train_patient][0])
        max_step = int(N//(window_size*overlap))
        for step in range(max_step):
            ecg = data[train_patient][0][step * int(window_size*overlap):step * int(window_size*overlap) + window_size] 
            resp = data[train_patient][1][step * int(window_size*overlap):step * int(window_size*overlap) + window_size]
            
            if (ecg.min() < ecg.max()):
                normalized_ecg = (ecg-ecg.min())/(ecg.max()-ecg.min())-0.5
                #zero_centered_ecg = ecg - np.mean(ecg)
                #normalized_ecg = zero_centered_ecg / np.std(zero_centered_ecg)
                resampled_ecg = signal.resample(normalized_ecg, downsampled_window_size)
                if resp.min() < resp.max():
                    normalized_resp = (resp-resp.min())/(resp.max()-resp.min())
                    #zero_centered_resp = resp - np.mean(resp)
                    #normalized_resp = zero_centered_resp / np.std(zero_centered_resp)
                    resampled_resp = signal.resample(normalized_resp, downsampled_window_size)
                    windows_ecg_train.append(np.float32(resampled_ecg))
                    windows_resp_train.append(np.float32(resampled_resp))
            
            
    windows_ecg_validation = []
    windows_resp_validation = []


    for validation_patient in validation_patients:
        N = len(data[validation_patient][0])
        max_step = int(N//(window_size*overlap))
        for step in range(max_step):
            ecg = data[validation_patient][0][step * int(window_size*overlap):step * int(window_size*overlap) + window_size] 
            resp = data[validation_patient][1][step * int(window_size*overlap):step * int(window_size*overlap) + window_size]
            
            if (ecg.min() < ecg.max()):
                normalized_ecg = (ecg-ecg.min())/(ecg.max()-ecg.min())-0.5
                #zero_centered_ecg = ecg - np.mean(ecg)
                #normalized_ecg = zero_centered_ecg / np.std(zero_centered_ecg)
                resampled_ecg = signal.resample(normalized_ecg, downsampled_window_size)
                if resp.min() < resp.max():
                    normalized_resp = (resp-resp.min())/(resp.max()-resp.min())
                    #zero_centered_resp = resp - np.mean(resp)
                    #normalized_resp = zero_centered_resp / np.std(zero_centered_resp)
                    resampled_resp = signal.resample(normalized_resp, downsampled_window_size)
                    windows_ecg_validation.append(np.float32(resampled_ecg))
                    windows_resp_validation.append(np.float32(resampled_resp))
          
    windows_ecg_test = []
    windows_resp_test = []
    
    for test_patient in test_patients:
        N = len(data[test_patient][0])
        max_step = int(N//(window_size*overlap))
        for step in range(max_step):
            ecg = data[test_patient][0][step * int(window_size*overlap):step * int(window_size*overlap) + window_size] 
            resp = data[test_patient][1][step * int(window_size*overlap):step * int(window_size*overlap) + window_size]
            
            if (ecg.min() < ecg.max()):
                normalized_ecg = (ecg-ecg.min())/(ecg.max()-ecg.min())-0.5
                #zero_centered_ecg = ecg - np.mean(ecg)
                #normalized_ecg = zero_centered_ecg / np.std(zero_centered_ecg)
                resampled_ecg = signal.resample(normalized_ecg, downsampled_window_size)
                if resp.min() < resp.max():
                    normalized_resp = (resp-resp.min())/(resp.max()-resp.min())
                    #zero_centered_resp = resp - np.mean(resp)
                    #normalized_resp = zero_centered_resp / np.std(zero_centered_resp)
                    resampled_resp = signal.resample(normalized_resp, downsampled_window_size)
                    windows_ecg_test.append(np.float32(resampled_ecg))
                    windows_resp_test.append(np.float32(resampled_resp))

    windows_ecg_train = np.stack(windows_ecg_train, axis=0)
    windows_resp_train = np.stack(windows_resp_train, axis=0)
    windows_ecg_validation = np.stack(windows_ecg_validation, axis=0)
    windows_resp_validation = np.stack(windows_resp_validation, axis=0)
    windows_ecg_test = np.stack(windows_ecg_test, axis=0)
    windows_resp_test = np.stack(windows_resp_test, axis=0)

    windows_ecg_train = windows_ecg_train[:,:,np.newaxis]
    windows_resp_train = windows_resp_train[:,:,np.newaxis]
    windows_ecg_validation = windows_ecg_validation[:,:,np.newaxis]
    windows_resp_validation = windows_resp_validation[:,:,np.newaxis]
    windows_ecg_test = windows_ecg_test[:,:,np.newaxis]
    windows_resp_test = windows_resp_test[:,:,np.newaxis]

    return windows_ecg_train, windows_resp_train, windows_ecg_validation, windows_resp_validation, windows_ecg_test, windows_resp_test


def process_data_segment(data, downsampled_window_size, patient_indices):
    window_size = int(downsampled_window_size * 0.9765625)
    overlap = 1 / 2

    windows_ecg = []
    windows_resp = []

    for record_index in patient_indices:
        N = len(data[record_index][0, :])
        max_step = int(N // (window_size * overlap))
        for step in range(1, max_step - 1):
            start_idx = int(step * window_size * overlap)
            end_idx = start_idx + window_size
            recrd_ecg = data[record_index][0, start_idx:end_idx]
            recrd_resp = data[record_index][1, start_idx:end_idx]

            if recrd_ecg.min() < recrd_ecg.max():  # Skip flatlined signal segments
                normalized_ecg = (recrd_ecg - recrd_ecg.min()) / (recrd_ecg.max() - recrd_ecg.min())
                normalized_ecg = signal.resample(normalized_ecg, downsampled_window_size)
                windows_ecg.append(np.float16(normalized_ecg))

                if recrd_resp.min() < recrd_resp.max():
                    normalized_resp = (recrd_resp - recrd_resp.min()) / (recrd_resp.max() - recrd_resp.min())
                    normalized_resp = signal.resample(normalized_resp, downsampled_window_size)
                    windows_resp.append(np.float16(normalized_resp))

    windows_ecg = np.array(windows_ecg)[:, :, np.newaxis]
    windows_resp = np.array(windows_resp)[:, :, np.newaxis]

    print(windows_ecg.shape)
    print(windows_resp.shape)

    return windows_ecg, windows_resp


def load_data():
     # bidmc
    path = "/Users/lanacaldarevic/workspace/phd/ecg_derived_resp_dl/data/bidmc-ppg-and-respiration-dataset-1.0.0"
    EXT = "*Signals.csv"
    all_csv_files = [file for path, subdir, files in os.walk(path) for file in glob(os.path.join(path, EXT))]
    patients = []
    data = {}
    no_errors = 0
    for file in all_csv_files:
        try:
            df = pd.read_csv(file)
            X1, X2, X3, X4 = df[' PLETH'].values, df[' V'].values, df[' AVR'].values, df[' II'].values
            # X = np.concatenate([X1.reshape(len(X1),1),X2.reshape(len(X1),1),X3.reshape(len(X1),1),X4.reshape(len(X1),1)], axis=1)
            
            Y = df[' RESP'].values
            
            patient = int(file.split('/')[-1].split('_')[1])
            patients.append(patient)
            #data[patient] = [X4, Y]
            data[patient] = np.array([X4, Y])
        except:
            no_errors += 1

    return data, patients

# %%
class VisualiseCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        fig, ax = plt.subplots(2,2)
        fig.suptitle('Ground truth vs. Prediction')
        for row in range(2):
            train_idx = random.randint(0, windows_ecg_train[:,:,:].shape[0]-1)
            val_idx = random.randint(0, windows_ecg_validation[:,:,:].shape[0]-1)
            to_predict_train = np.array([windows_ecg_train[train_idx,:,:]])
            ground_truth_train = windows_resp_train[train_idx,:,:]
            prediction_train = self.model.predict(to_predict_train)[0] 
            prediction_train_score=self.model.evaluate(to_predict_train,np.array([ground_truth_train]))
            to_predict_validation = np.array([windows_ecg_validation[val_idx,:,:]])
            ground_truth_validation = windows_resp_validation[val_idx,:,:]
            prediction_validation = self.model.predict(to_predict_validation)[0]
            prediction_validation_score = self.model.evaluate(to_predict_validation, np.array([ground_truth_validation]))
            ax[row,0].plot(ground_truth_train, label='Ground Truth')
            ax[row,0].plot(prediction_train, label='Prediction')
            ax[row,0].set_title("Train L "+str(prediction_train_score[0])[:6]+" CC "+str(prediction_train_score[2])[:6])
            ax[row,0].legend()
            
            ax[row,1].plot(ground_truth_validation, label='Ground Truth')
            ax[row,1].plot(prediction_validation, label='Prediction')
            ax[row,1].set_title("Valid L "+str(prediction_validation_score[0])[:6]+" CC "+str(prediction_validation_score[2])[:6])
            ax[row,1].legend()
            
            plt.tight_layout()
            
            
        wandb.log({
            "predictions_visualization": wandb.Image(fig)

        }, commit=False)
        plt.close(fig)

def correlation(x, y): #todo: check this and see in papers what cross correlation is
    # Normalize y to the [0, 1] range
    min_y = tf.math.reduce_min(y)
    max_y = tf.math.reduce_max(y)
    r_up = tf.math.subtract(y, min_y)
    r_down = max_y - min_y
    new_y = r_up / r_down
    
    # Compute means
    mx = tf.math.reduce_mean(x)
    my = tf.math.reduce_mean(new_y)
    
    # Compute centered values
    xm, ym = x - mx, new_y - my
    
    # Compute correlation coefficient
    r_num = tf.reduce_sum(tf.multiply(xm, ym))
    r_den = tf.sqrt(tf.multiply(tf.reduce_sum(tf.square(xm)), tf.reduce_sum(tf.square(ym))))
    r = r_num / r_den
    
    # Ensure the result is between -1 and 1
    r = tf.maximum(tf.minimum(r, 1.0), -1.0)
    
    return 1 - r

def cross_correlation(y_true, y_pred):
    """ Compute cross-correlation between true and predicted signals. """
    y_true_mean = tf.reduce_mean(y_true, axis=1, keepdims=True)
    y_pred_mean = tf.reduce_mean(y_pred, axis=1, keepdims=True)
    
    y_true_std = tf.math.reduce_std(y_true, axis=1, keepdims=True)
    y_pred_std = tf.math.reduce_std(y_pred, axis=1, keepdims=True)

    norm_y_true = (y_true - y_true_mean) / y_true_std
    norm_y_pred = (y_pred - y_pred_mean) / y_pred_std

    correlation = tf.reduce_mean(norm_y_true * norm_y_pred, axis=1)
    return tf.reduce_mean(correlation)

# %%
import datetime
def train(config):
    lr = config.learning_rate
    optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=lr, beta_1=0.9, beta_2=0.999, amsgrad=False)
    
    model = create_model(config)
    
    # define callbacks
    #reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.01, patience=10, cooldown=5, mode='min', min_lr=0.0000001)
    filepath = os.path.join('CV_results', f'model_crossval{config.split_ind}-size{config.start_filters}-input{config.input_size}-lr{config.learning_rate}-kernel{config.kernel_size}-reg{config.reg}-dropout{config.dropout}.h5')
    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    
    # early stopping
    early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, start_from_epoch=20, restore_best_weights=True)
    

    log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, update_freq='epoch')
    callbacks = [checkpoint, early_stopping]

    """ 
    # Hubner
    loss = tf.keras.losses.Huber()
    model.compile(loss=loss, metrics=[correlation, 'mse'], optimizer=optimizer)
    """

    #optimizer = tf.keras.optimizers.legacy.RMSprop(lr=lr, momentum=0.7)
    optimizer = tf.keras.optimizers.legacy.SGD(lr=lr, momentum=0.7)

    model.compile(loss='mse', metrics=['mse', correlation, cross_correlation], optimizer=optimizer)
    
    print("Model training starting")
    model.fit(windows_ecg_train, windows_resp_train,
              epochs=config.epochs,
              batch_size=config.batch_size,
              shuffle=True,
              callbacks=callbacks,
              validation_data=(windows_ecg_validation, windows_resp_validation))
    
    model.save(os.path.join('CV_results', f'combined_model{config.split_ind}-size{config.start_filters}-input{config.input_size}-lr{config.learning_rate}-kernel{config.kernel_size}-reg{config.reg}-dropout{config.dropout}.h5'))

    return model

# %%
sampling_rate = 125
input_size_seconds = 16 # //2, *2
downsampled_window_size = 1024 #? power of 2
window_size = input_size_seconds * sampling_rate
overlap = 0.5 #25%

data, patients = load_data()

# %%
np.random.seed(42)
unique_patients = list(set(patients))
np.random.shuffle(unique_patients)

train_val_patients, test_patients = train_test_split(unique_patients, test_size=0.20, random_state=42)

# %%
start_filters = 8
input_size = downsampled_window_size

# %%
class ModelConfig:
    def __init__(self, learning_rate, epochs, batch_size, start_filters, input_size, kernel_size, reg, dropout, split_ind):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.batch_size = batch_size
        self.start_filters = start_filters
        self.input_size = input_size
        self.kernel_size = kernel_size
        self.reg = reg
        self.dropout = dropout
        self.split_ind = split_ind

# %%
results_mse = []
results_corr = []
results_cc = []

kf = KFold(n_splits=5, shuffle=True, random_state=42)
for split_index, (train_index, val_index) in enumerate(kf.split(train_val_patients)):
    train_patients = [train_val_patients[i] for i in train_index]
    val_patients = [train_val_patients[i] for i in val_index]

    windows_ecg_train, windows_resp_train = process_data_segment(data, downsampled_window_size, train_patients)
    windows_ecg_validation, windows_resp_validation = process_data_segment(data, downsampled_window_size, val_patients)

    config = {
        "learning_rate": 0.004878689057515219,
        "epochs": 500,
        "batch_size": 256,
        "start_filters": start_filters,
        "input_size": input_size,
        "kernel_size": 27,
        "reg": 0.006032564292289038,
        "dropout": 0.8804727366138194,
        "split_ind": split_index
    }
    config = ModelConfig(**config)
    model = train(config)
    _, mse, corr, cc = model.evaluate(windows_ecg_validation, windows_resp_validation)
    results_mse.append(mse)
    results_corr.append(corr)
    results_cc.append(cc)

# Output the results from all folds
# Out:
# (3304, 1024, 1)
# (3304, 1024, 1)
# (944, 1024, 1)
# (944, 1024, 1)
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 1024, 1)]            0         []
#
#  conv1d_65 (Conv1D)          (None, 1024, 8)              224       ['input_6[0][0]']
#
#  batch_normalization_60 (Ba  (None, 1024, 8)              32        ['conv1d_65[0][0]']
#  tchNormalization)
#
#  conv1d_66 (Conv1D)          (None, 1024, 8)              1736      ['batch_normalization_60[0][0]
#                                                                     ']
#
#  batch_normalization_61 (Ba  (None, 1024, 8)              32        ['conv1d_66[0][0]']
#  tchNormalization)
#
#  max_pooling1d_10 (MaxPooli  (None, 512, 8)               0         ['batch_normalization_61[0][0]
#  ng1D)                                                              ']
#
#  conv1d_67 (Conv1D)          (None, 512, 16)              3472      ['max_pooling1d_10[0][0]']
#
#  batch_normalization_62 (Ba  (None, 512, 16)              64        ['conv1d_67[0][0]']
#  tchNormalization)
#
#  conv1d_68 (Conv1D)          (None, 512, 16)              6928      ['batch_normalization_62[0][0]
#                                                                     ']
#
#  batch_normalization_63 (Ba  (None, 512, 16)              64        ['conv1d_68[0][0]']
#  tchNormalization)
#
#  dropout_10 (Dropout)        (None, 512, 16)              0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  max_pooling1d_11 (MaxPooli  (None, 256, 16)              0         ['dropout_10[0][0]']
#  ng1D)
#
#  conv1d_69 (Conv1D)          (None, 256, 32)              13856     ['max_pooling1d_11[0][0]']
#
#  batch_normalization_64 (Ba  (None, 256, 32)              128       ['conv1d_69[0][0]']
#  tchNormalization)
#
#  conv1d_70 (Conv1D)          (None, 256, 32)              27680     ['batch_normalization_64[0][0]
#                                                                     ']
#
#  batch_normalization_65 (Ba  (None, 256, 32)              128       ['conv1d_70[0][0]']
#  tchNormalization)
#
#  up_sampling1d_10 (UpSampli  (None, 512, 32)              0         ['batch_normalization_65[0][0]
#  ng1D)                                                              ']
#
#  conv1d_71 (Conv1D)          (None, 512, 32)              2080      ['up_sampling1d_10[0][0]']
#
#  batch_normalization_66 (Ba  (None, 512, 32)              128       ['conv1d_71[0][0]']
#  tchNormalization)
#
#  concatenate_10 (Concatenat  (None, 512, 48)              0         ['dropout_10[0][0]',
#  e)                                                                  'batch_normalization_66[0][0]
#                                                                     ']
#
#  conv1d_72 (Conv1D)          (None, 512, 16)              20752     ['concatenate_10[0][0]']
#
#  batch_normalization_67 (Ba  (None, 512, 16)              64        ['conv1d_72[0][0]']
#  tchNormalization)
#
#  conv1d_73 (Conv1D)          (None, 512, 16)              6928      ['batch_normalization_67[0][0]
#                                                                     ']
#
#  batch_normalization_68 (Ba  (None, 512, 16)              64        ['conv1d_73[0][0]']
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 512, 16)              0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  up_sampling1d_11 (UpSampli  (None, 1024, 16)             0         ['dropout_11[0][0]']
#  ng1D)
#
#  conv1d_74 (Conv1D)          (None, 1024, 16)             528       ['up_sampling1d_11[0][0]']
#
#  batch_normalization_69 (Ba  (None, 1024, 16)             64        ['conv1d_74[0][0]']
#  tchNormalization)
#
#  concatenate_11 (Concatenat  (None, 1024, 24)             0         ['batch_normalization_61[0][0]
#  e)                                                                 ',
#                                                                      'batch_normalization_69[0][0]
#                                                                     ']
#
#  conv1d_75 (Conv1D)          (None, 1024, 8)              5192      ['concatenate_11[0][0]']
#
#  batch_normalization_70 (Ba  (None, 1024, 8)              32        ['conv1d_75[0][0]']
#  tchNormalization)
#
#  conv1d_76 (Conv1D)          (None, 1024, 8)              1736      ['batch_normalization_70[0][0]
#                                                                     ']
#
#  batch_normalization_71 (Ba  (None, 1024, 8)              32        ['conv1d_76[0][0]']
#  tchNormalization)
#
#  conv1d_77 (Conv1D)          (None, 1024, 1)              217       ['batch_normalization_71[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 92161 (360.00 KB)
# Trainable params: 91745 (358.38 KB)
# Non-trainable params: 416 (1.62 KB)
# __________________________________________________________________________________________________
# Model training starting
# /Users/lanacaldarevic/miniforge3/envs/tf_m1/lib/python3.9/site-packages/keras/src/optimizers/legacy/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/500
# 2024-04-17 19:55:50.676891: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 13/13 [==============================] - ETA: 0s - loss: 2.1119 - mse: 0.1887 - correlation: 1.0000 - cross_correlation: 0.0057
# 2024-04-17 19:56:43.256110: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 2.02376, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 59s 2s/step - loss: 2.1119 - mse: 0.1887 - correlation: 1.0000 - cross_correlation: 0.0057 - val_loss: 2.0238 - val_mse: 0.1055 - val_correlation: 0.9386 - val_cross_correlation: 0.0491
# Epoch 2/500
# /Users/lanacaldarevic/miniforge3/envs/tf_m1/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 13/13 [==============================] - ETA: 0s - loss: 2.0991 - mse: 0.1853 - correlation: 0.9995 - cross_correlation: 0.0066
# Epoch 2: val_loss improved from 2.02376 to 2.01309, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 11s 798ms/step - loss: 2.0991 - mse: 0.1853 - correlation: 0.9995 - cross_correlation: 0.0066 - val_loss: 2.0131 - val_mse: 0.1046 - val_correlation: 0.9948 - val_cross_correlation: 0.0226
# Epoch 3/500
# 13/13 [==============================] - ETA: 0s - loss: 2.0863 - mse: 0.1822 - correlation: 1.0006 - cross_correlation: 0.0050
# Epoch 3: val_loss improved from 2.01309 to 2.00341, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 10s 792ms/step - loss: 2.0863 - mse: 0.1822 - correlation: 1.0006 - cross_correlation: 0.0050 - val_loss: 2.0034 - val_mse: 0.1046 - val_correlation: 1.0054 - val_cross_correlation: 0.0103
# Epoch 4/500
# 13/13 [==============================] - ETA: 0s - loss: 2.0733 - mse: 0.1789 - correlation: 0.9995 - cross_correlation: 0.0059
# Epoch 4: val_loss improved from 2.00341 to 1.99410, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 9s 676ms/step - loss: 2.0733 - mse: 0.1789 - correlation: 0.9995 - cross_correlation: 0.0059 - val_loss: 1.9941 - val_mse: 0.1050 - val_correlation: 1.0044 - val_cross_correlation: 0.0076
# Epoch 5/500
# 13/13 [==============================] - ETA: 0s - loss: 2.0606 - mse: 0.1759 - correlation: 0.9993 - cross_correlation: 0.0058
# Epoch 5: val_loss improved from 1.99410 to 1.98494, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 608ms/step - loss: 2.0606 - mse: 0.1759 - correlation: 0.9993 - cross_correlation: 0.0058 - val_loss: 1.9849 - val_mse: 0.1054 - val_correlation: 1.0008 - val_cross_correlation: 0.0063
# Epoch 6/500
# 13/13 [==============================] - ETA: 0s - loss: 2.0484 - mse: 0.1733 - correlation: 0.9990 - cross_correlation: 0.0055
# Epoch 6: val_loss improved from 1.98494 to 1.97587, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 662ms/step - loss: 2.0484 - mse: 0.1733 - correlation: 0.9990 - cross_correlation: 0.0055 - val_loss: 1.9759 - val_mse: 0.1059 - val_correlation: 0.9987 - val_cross_correlation: 0.0028
# Epoch 7/500
# 13/13 [==============================] - ETA: 0s - loss: 2.0363 - mse: 0.1707 - correlation: 0.9983 - cross_correlation: 0.0051
# Epoch 7: val_loss improved from 1.97587 to 1.96677, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 9s 752ms/step - loss: 2.0363 - mse: 0.1707 - correlation: 0.9983 - cross_correlation: 0.0051 - val_loss: 1.9668 - val_mse: 0.1063 - val_correlation: 0.9970 - val_cross_correlation: 1.6844e-05
# Epoch 8/500
# 13/13 [==============================] - ETA: 0s - loss: 2.0244 - mse: 0.1683 - correlation: 0.9976 - cross_correlation: 0.0050
# Epoch 8: val_loss improved from 1.96677 to 1.95756, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 665ms/step - loss: 2.0244 - mse: 0.1683 - correlation: 0.9976 - cross_correlation: 0.0050 - val_loss: 1.9576 - val_mse: 0.1066 - val_correlation: 0.9957 - val_cross_correlation: -0.0015
# Epoch 9/500
# 13/13 [==============================] - ETA: 0s - loss: 2.0126 - mse: 0.1660 - correlation: 0.9960 - cross_correlation: 0.0059
# Epoch 9: val_loss improved from 1.95756 to 1.94841, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 614ms/step - loss: 2.0126 - mse: 0.1660 - correlation: 0.9960 - cross_correlation: 0.0059 - val_loss: 1.9484 - val_mse: 0.1069 - val_correlation: 0.9953 - val_cross_correlation: -0.0023
# Epoch 10/500
# 13/13 [==============================] - ETA: 0s - loss: 2.0016 - mse: 0.1643 - correlation: 0.9973 - cross_correlation: 0.0031
# Epoch 10: val_loss improved from 1.94841 to 1.93921, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 631ms/step - loss: 2.0016 - mse: 0.1643 - correlation: 0.9973 - cross_correlation: 0.0031 - val_loss: 1.9392 - val_mse: 0.1071 - val_correlation: 0.9958 - val_cross_correlation: -0.0029
# Epoch 11/500
# 13/13 [==============================] - ETA: 0s - loss: 1.9902 - mse: 0.1623 - correlation: 0.9960 - cross_correlation: 0.0042
# Epoch 11: val_loss improved from 1.93921 to 1.92996, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 647ms/step - loss: 1.9902 - mse: 0.1623 - correlation: 0.9960 - cross_correlation: 0.0042 - val_loss: 1.9300 - val_mse: 0.1071 - val_correlation: 0.9953 - val_cross_correlation: -0.0028
# Epoch 12/500
# 13/13 [==============================] - ETA: 0s - loss: 1.9791 - mse: 0.1605 - correlation: 0.9952 - cross_correlation: 0.0042
# Epoch 12: val_loss improved from 1.92996 to 1.92084, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 637ms/step - loss: 1.9791 - mse: 0.1605 - correlation: 0.9952 - cross_correlation: 0.0042 - val_loss: 1.9208 - val_mse: 0.1073 - val_correlation: 0.9970 - val_cross_correlation: -0.0031
# Epoch 13/500
# 13/13 [==============================] - ETA: 0s - loss: 1.9684 - mse: 0.1591 - correlation: 0.9955 - cross_correlation: 0.0034
# Epoch 13: val_loss improved from 1.92084 to 1.91168, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 9s 681ms/step - loss: 1.9684 - mse: 0.1591 - correlation: 0.9955 - cross_correlation: 0.0034 - val_loss: 1.9117 - val_mse: 0.1074 - val_correlation: 0.9989 - val_cross_correlation: -0.0030
# Epoch 14/500
# 13/13 [==============================] - ETA: 0s - loss: 1.9578 - mse: 0.1577 - correlation: 0.9952 - cross_correlation: 0.0029
# Epoch 14: val_loss improved from 1.91168 to 1.90256, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 597ms/step - loss: 1.9578 - mse: 0.1577 - correlation: 0.9952 - cross_correlation: 0.0029 - val_loss: 1.9026 - val_mse: 0.1074 - val_correlation: 1.0004 - val_cross_correlation: -0.0029
# Epoch 15/500
# 13/13 [==============================] - ETA: 0s - loss: 1.9471 - mse: 0.1561 - correlation: 0.9934 - cross_correlation: 0.0040
# Epoch 15: val_loss improved from 1.90256 to 1.89352, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 552ms/step - loss: 1.9471 - mse: 0.1561 - correlation: 0.9934 - cross_correlation: 0.0040 - val_loss: 1.8935 - val_mse: 0.1075 - val_correlation: 1.0035 - val_cross_correlation: -0.0030
# Epoch 16/500
# 13/13 [==============================] - ETA: 0s - loss: 1.9366 - mse: 0.1548 - correlation: 0.9924 - cross_correlation: 0.0042
# Epoch 16: val_loss improved from 1.89352 to 1.88442, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 624ms/step - loss: 1.9366 - mse: 0.1548 - correlation: 0.9924 - cross_correlation: 0.0042 - val_loss: 1.8844 - val_mse: 0.1075 - val_correlation: 1.0056 - val_cross_correlation: -0.0024
# Epoch 17/500
# 13/13 [==============================] - ETA: 0s - loss: 1.9265 - mse: 0.1537 - correlation: 0.9929 - cross_correlation: 0.0035
# Epoch 17: val_loss improved from 1.88442 to 1.87538, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 630ms/step - loss: 1.9265 - mse: 0.1537 - correlation: 0.9929 - cross_correlation: 0.0035 - val_loss: 1.8754 - val_mse: 0.1075 - val_correlation: 1.0051 - val_cross_correlation: -0.0011
# Epoch 18/500
# 13/13 [==============================] - ETA: 0s - loss: 1.9163 - mse: 0.1526 - correlation: 0.9925 - cross_correlation: 0.0026
# Epoch 18: val_loss improved from 1.87538 to 1.86655, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 583ms/step - loss: 1.9163 - mse: 0.1526 - correlation: 0.9925 - cross_correlation: 0.0026 - val_loss: 1.8666 - val_mse: 0.1077 - val_correlation: 1.0087 - val_cross_correlation: -6.1965e-04
# Epoch 19/500
# 13/13 [==============================] - ETA: 0s - loss: 1.9063 - mse: 0.1515 - correlation: 0.9920 - cross_correlation: 0.0025
# Epoch 19: val_loss improved from 1.86655 to 1.85764, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 514ms/step - loss: 1.9063 - mse: 0.1515 - correlation: 0.9920 - cross_correlation: 0.0025 - val_loss: 1.8576 - val_mse: 0.1077 - val_correlation: 1.0093 - val_cross_correlation: 6.3901e-04
# Epoch 20/500
# 13/13 [==============================] - ETA: 0s - loss: 1.8963 - mse: 0.1505 - correlation: 0.9910 - cross_correlation: 0.0029
# Epoch 20: val_loss improved from 1.85764 to 1.84877, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 609ms/step - loss: 1.8963 - mse: 0.1505 - correlation: 0.9910 - cross_correlation: 0.0029 - val_loss: 1.8488 - val_mse: 0.1078 - val_correlation: 1.0089 - val_cross_correlation: 0.0021
# Epoch 21/500
# 13/13 [==============================] - ETA: 0s - loss: 1.8864 - mse: 0.1495 - correlation: 0.9904 - cross_correlation: 0.0039
# Epoch 21: val_loss improved from 1.84877 to 1.83986, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 9s 690ms/step - loss: 1.8864 - mse: 0.1495 - correlation: 0.9904 - cross_correlation: 0.0039 - val_loss: 1.8399 - val_mse: 0.1077 - val_correlation: 1.0070 - val_cross_correlation: 0.0041
# Epoch 22/500
# 13/13 [==============================] - ETA: 0s - loss: 1.8769 - mse: 0.1488 - correlation: 0.9914 - cross_correlation: 0.0019
# Epoch 22: val_loss improved from 1.83986 to 1.83110, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 541ms/step - loss: 1.8769 - mse: 0.1488 - correlation: 0.9914 - cross_correlation: 0.0019 - val_loss: 1.8311 - val_mse: 0.1078 - val_correlation: 1.0074 - val_cross_correlation: 0.0056
# Epoch 23/500
# 13/13 [==============================] - ETA: 0s - loss: 1.8671 - mse: 0.1478 - correlation: 0.9890 - cross_correlation: 0.0037
# Epoch 23: val_loss improved from 1.83110 to 1.82225, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 563ms/step - loss: 1.8671 - mse: 0.1478 - correlation: 0.9890 - cross_correlation: 0.0037 - val_loss: 1.8222 - val_mse: 0.1077 - val_correlation: 1.0064 - val_cross_correlation: 0.0074
# Epoch 24/500
# 13/13 [==============================] - ETA: 0s - loss: 1.8576 - mse: 0.1471 - correlation: 0.9891 - cross_correlation: 0.0030
# Epoch 24: val_loss improved from 1.82225 to 1.81364, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 602ms/step - loss: 1.8576 - mse: 0.1471 - correlation: 0.9891 - cross_correlation: 0.0030 - val_loss: 1.8136 - val_mse: 0.1078 - val_correlation: 1.0082 - val_cross_correlation: 0.0084
# Epoch 25/500
# 13/13 [==============================] - ETA: 0s - loss: 1.8482 - mse: 0.1464 - correlation: 0.9884 - cross_correlation: 0.0038
# Epoch 25: val_loss improved from 1.81364 to 1.80482, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 6s 458ms/step - loss: 1.8482 - mse: 0.1464 - correlation: 0.9884 - cross_correlation: 0.0038 - val_loss: 1.8048 - val_mse: 0.1077 - val_correlation: 1.0054 - val_cross_correlation: 0.0103
# Epoch 26/500
# 13/13 [==============================] - ETA: 0s - loss: 1.8389 - mse: 0.1457 - correlation: 0.9887 - cross_correlation: 0.0031
# Epoch 26: val_loss improved from 1.80482 to 1.79619, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 546ms/step - loss: 1.8389 - mse: 0.1457 - correlation: 0.9887 - cross_correlation: 0.0031 - val_loss: 1.7962 - val_mse: 0.1077 - val_correlation: 1.0053 - val_cross_correlation: 0.0114
# Epoch 27/500
# 13/13 [==============================] - ETA: 0s - loss: 1.8294 - mse: 0.1449 - correlation: 0.9863 - cross_correlation: 0.0044
# Epoch 27: val_loss improved from 1.79619 to 1.78762, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 511ms/step - loss: 1.8294 - mse: 0.1449 - correlation: 0.9863 - cross_correlation: 0.0044 - val_loss: 1.7876 - val_mse: 0.1077 - val_correlation: 1.0068 - val_cross_correlation: 0.0119
# Epoch 28/500
# 13/13 [==============================] - ETA: 0s - loss: 1.8204 - mse: 0.1444 - correlation: 0.9877 - cross_correlation: 0.0031
# Epoch 28: val_loss improved from 1.78762 to 1.77903, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 592ms/step - loss: 1.8204 - mse: 0.1444 - correlation: 0.9877 - cross_correlation: 0.0031 - val_loss: 1.7790 - val_mse: 0.1077 - val_correlation: 1.0057 - val_cross_correlation: 0.0127
# Epoch 29/500
# 13/13 [==============================] - ETA: 0s - loss: 1.8112 - mse: 0.1438 - correlation: 0.9867 - cross_correlation: 0.0038
# Epoch 29: val_loss improved from 1.77903 to 1.77065, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 658ms/step - loss: 1.8112 - mse: 0.1438 - correlation: 0.9867 - cross_correlation: 0.0038 - val_loss: 1.7706 - val_mse: 0.1078 - val_correlation: 1.0083 - val_cross_correlation: 0.0125
# Epoch 30/500
# 13/13 [==============================] - ETA: 0s - loss: 1.8022 - mse: 0.1433 - correlation: 0.9863 - cross_correlation: 0.0040
# Epoch 30: val_loss improved from 1.77065 to 1.76222, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 6s 499ms/step - loss: 1.8022 - mse: 0.1433 - correlation: 0.9863 - cross_correlation: 0.0040 - val_loss: 1.7622 - val_mse: 0.1078 - val_correlation: 1.0101 - val_cross_correlation: 0.0123
# Epoch 31/500
# 13/13 [==============================] - ETA: 0s - loss: 1.7932 - mse: 0.1426 - correlation: 0.9847 - cross_correlation: 0.0050
# Epoch 31: val_loss improved from 1.76222 to 1.75368, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 583ms/step - loss: 1.7932 - mse: 0.1426 - correlation: 0.9847 - cross_correlation: 0.0050 - val_loss: 1.7537 - val_mse: 0.1077 - val_correlation: 1.0090 - val_cross_correlation: 0.0128
# Epoch 32/500
# 13/13 [==============================] - ETA: 0s - loss: 1.7844 - mse: 0.1423 - correlation: 0.9861 - cross_correlation: 0.0029
# Epoch 32: val_loss improved from 1.75368 to 1.74540, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 9s 669ms/step - loss: 1.7844 - mse: 0.1423 - correlation: 0.9861 - cross_correlation: 0.0029 - val_loss: 1.7454 - val_mse: 0.1078 - val_correlation: 1.0105 - val_cross_correlation: 0.0124
# Epoch 33/500
# 13/13 [==============================] - ETA: 0s - loss: 1.7755 - mse: 0.1418 - correlation: 0.9852 - cross_correlation: 0.0036
# Epoch 33: val_loss improved from 1.74540 to 1.73700, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 659ms/step - loss: 1.7755 - mse: 0.1418 - correlation: 0.9852 - cross_correlation: 0.0036 - val_loss: 1.7370 - val_mse: 0.1078 - val_correlation: 1.0096 - val_cross_correlation: 0.0126
# Epoch 34/500
# 13/13 [==============================] - ETA: 0s - loss: 1.7667 - mse: 0.1413 - correlation: 0.9847 - cross_correlation: 0.0049
# Epoch 34: val_loss improved from 1.73700 to 1.72878, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 546ms/step - loss: 1.7667 - mse: 0.1413 - correlation: 0.9847 - cross_correlation: 0.0049 - val_loss: 1.7288 - val_mse: 0.1078 - val_correlation: 1.0116 - val_cross_correlation: 0.0118
# Epoch 35/500
# 13/13 [==============================] - ETA: 0s - loss: 1.7580 - mse: 0.1409 - correlation: 0.9845 - cross_correlation: 0.0041
# Epoch 35: val_loss improved from 1.72878 to 1.72034, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 6s 498ms/step - loss: 1.7580 - mse: 0.1409 - correlation: 0.9845 - cross_correlation: 0.0041 - val_loss: 1.7203 - val_mse: 0.1076 - val_correlation: 1.0095 - val_cross_correlation: 0.0120
# Epoch 36/500
# 13/13 [==============================] - ETA: 0s - loss: 1.7493 - mse: 0.1404 - correlation: 0.9831 - cross_correlation: 0.0053
# Epoch 36: val_loss improved from 1.72034 to 1.71235, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 559ms/step - loss: 1.7493 - mse: 0.1404 - correlation: 0.9831 - cross_correlation: 0.0053 - val_loss: 1.7123 - val_mse: 0.1079 - val_correlation: 1.0132 - val_cross_correlation: 0.0106
# Epoch 37/500
# 13/13 [==============================] - ETA: 0s - loss: 1.7407 - mse: 0.1400 - correlation: 0.9821 - cross_correlation: 0.0061
# Epoch 37: val_loss improved from 1.71235 to 1.70422, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 552ms/step - loss: 1.7407 - mse: 0.1400 - correlation: 0.9821 - cross_correlation: 0.0061 - val_loss: 1.7042 - val_mse: 0.1079 - val_correlation: 1.0152 - val_cross_correlation: 0.0095
# Epoch 38/500
# 13/13 [==============================] - ETA: 0s - loss: 1.7322 - mse: 0.1396 - correlation: 0.9815 - cross_correlation: 0.0050
# Epoch 38: val_loss improved from 1.70422 to 1.69611, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 575ms/step - loss: 1.7322 - mse: 0.1396 - correlation: 0.9815 - cross_correlation: 0.0050 - val_loss: 1.6961 - val_mse: 0.1079 - val_correlation: 1.0167 - val_cross_correlation: 0.0084
# Epoch 39/500
# 13/13 [==============================] - ETA: 0s - loss: 1.7236 - mse: 0.1392 - correlation: 0.9801 - cross_correlation: 0.0062
# Epoch 39: val_loss improved from 1.69611 to 1.68790, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 588ms/step - loss: 1.7236 - mse: 0.1392 - correlation: 0.9801 - cross_correlation: 0.0062 - val_loss: 1.6879 - val_mse: 0.1078 - val_correlation: 1.0149 - val_cross_correlation: 0.0084
# Epoch 40/500
# 13/13 [==============================] - ETA: 0s - loss: 1.7153 - mse: 0.1389 - correlation: 0.9806 - cross_correlation: 0.0064
# Epoch 40: val_loss improved from 1.68790 to 1.67997, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 515ms/step - loss: 1.7153 - mse: 0.1389 - correlation: 0.9806 - cross_correlation: 0.0064 - val_loss: 1.6800 - val_mse: 0.1079 - val_correlation: 1.0179 - val_cross_correlation: 0.0069
# Epoch 41/500
# 13/13 [==============================] - ETA: 0s - loss: 1.7070 - mse: 0.1386 - correlation: 0.9807 - cross_correlation: 0.0057
# Epoch 41: val_loss improved from 1.67997 to 1.67195, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 654ms/step - loss: 1.7070 - mse: 0.1386 - correlation: 0.9807 - cross_correlation: 0.0057 - val_loss: 1.6720 - val_mse: 0.1079 - val_correlation: 1.0187 - val_cross_correlation: 0.0060
# Epoch 42/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6987 - mse: 0.1383 - correlation: 0.9811 - cross_correlation: 0.0053
# Epoch 42: val_loss improved from 1.67195 to 1.66394, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 564ms/step - loss: 1.6987 - mse: 0.1383 - correlation: 0.9811 - cross_correlation: 0.0053 - val_loss: 1.6639 - val_mse: 0.1078 - val_correlation: 1.0185 - val_cross_correlation: 0.0055
# Epoch 43/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6903 - mse: 0.1379 - correlation: 0.9788 - cross_correlation: 0.0068
# Epoch 43: val_loss improved from 1.66394 to 1.65612, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 6s 500ms/step - loss: 1.6903 - mse: 0.1379 - correlation: 0.9788 - cross_correlation: 0.0068 - val_loss: 1.6561 - val_mse: 0.1079 - val_correlation: 1.0205 - val_cross_correlation: 0.0042
# Epoch 44/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6821 - mse: 0.1375 - correlation: 0.9776 - cross_correlation: 0.0083
# Epoch 44: val_loss improved from 1.65612 to 1.64832, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 590ms/step - loss: 1.6821 - mse: 0.1375 - correlation: 0.9776 - cross_correlation: 0.0083 - val_loss: 1.6483 - val_mse: 0.1080 - val_correlation: 1.0219 - val_cross_correlation: 0.0031
# Epoch 45/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6740 - mse: 0.1373 - correlation: 0.9775 - cross_correlation: 0.0077
# Epoch 45: val_loss improved from 1.64832 to 1.64037, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 599ms/step - loss: 1.6740 - mse: 0.1373 - correlation: 0.9775 - cross_correlation: 0.0077 - val_loss: 1.6404 - val_mse: 0.1079 - val_correlation: 1.0215 - val_cross_correlation: 0.0026
# Epoch 46/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6659 - mse: 0.1370 - correlation: 0.9773 - cross_correlation: 0.0071
# Epoch 46: val_loss improved from 1.64037 to 1.63266, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 531ms/step - loss: 1.6659 - mse: 0.1370 - correlation: 0.9773 - cross_correlation: 0.0071 - val_loss: 1.6327 - val_mse: 0.1080 - val_correlation: 1.0238 - val_cross_correlation: 0.0013
# Epoch 47/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6579 - mse: 0.1368 - correlation: 0.9766 - cross_correlation: 0.0076
# Epoch 47: val_loss improved from 1.63266 to 1.62496, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 9s 683ms/step - loss: 1.6579 - mse: 0.1368 - correlation: 0.9766 - cross_correlation: 0.0076 - val_loss: 1.6250 - val_mse: 0.1081 - val_correlation: 1.0253 - val_cross_correlation: 2.0895e-04
# Epoch 48/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6499 - mse: 0.1366 - correlation: 0.9770 - cross_correlation: 0.0070
# Epoch 48: val_loss improved from 1.62496 to 1.61723, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 6s 458ms/step - loss: 1.6499 - mse: 0.1366 - correlation: 0.9770 - cross_correlation: 0.0070 - val_loss: 1.6172 - val_mse: 0.1081 - val_correlation: 1.0260 - val_cross_correlation: -6.0323e-04
# Epoch 49/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6420 - mse: 0.1363 - correlation: 0.9760 - cross_correlation: 0.0077
# Epoch 49: val_loss improved from 1.61723 to 1.60944, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 9s 686ms/step - loss: 1.6420 - mse: 0.1363 - correlation: 0.9760 - cross_correlation: 0.0077 - val_loss: 1.6094 - val_mse: 0.1080 - val_correlation: 1.0250 - val_cross_correlation: -8.0807e-04
# Epoch 50/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6341 - mse: 0.1361 - correlation: 0.9764 - cross_correlation: 0.0075
# Epoch 50: val_loss improved from 1.60944 to 1.60199, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 649ms/step - loss: 1.6341 - mse: 0.1361 - correlation: 0.9764 - cross_correlation: 0.0075 - val_loss: 1.6020 - val_mse: 0.1082 - val_correlation: 1.0284 - val_cross_correlation: -0.0025
# Epoch 51/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6261 - mse: 0.1358 - correlation: 0.9745 - cross_correlation: 0.0087
# Epoch 51: val_loss improved from 1.60199 to 1.59429, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 512ms/step - loss: 1.6261 - mse: 0.1358 - correlation: 0.9745 - cross_correlation: 0.0087 - val_loss: 1.5943 - val_mse: 0.1081 - val_correlation: 1.0277 - val_cross_correlation: -0.0027
# Epoch 52/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6184 - mse: 0.1356 - correlation: 0.9750 - cross_correlation: 0.0084
# Epoch 52: val_loss improved from 1.59429 to 1.58671, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 560ms/step - loss: 1.6184 - mse: 0.1356 - correlation: 0.9750 - cross_correlation: 0.0084 - val_loss: 1.5867 - val_mse: 0.1080 - val_correlation: 1.0277 - val_cross_correlation: -0.0030
# Epoch 53/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6106 - mse: 0.1354 - correlation: 0.9732 - cross_correlation: 0.0085
# Epoch 53: val_loss improved from 1.58671 to 1.57943, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 9s 718ms/step - loss: 1.6106 - mse: 0.1354 - correlation: 0.9732 - cross_correlation: 0.0085 - val_loss: 1.5794 - val_mse: 0.1083 - val_correlation: 1.0322 - val_cross_correlation: -0.0051
# Epoch 54/500
# 13/13 [==============================] - ETA: 0s - loss: 1.6029 - mse: 0.1352 - correlation: 0.9733 - cross_correlation: 0.0084
# Epoch 54: val_loss improved from 1.57943 to 1.57189, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 9s 645ms/step - loss: 1.6029 - mse: 0.1352 - correlation: 0.9733 - cross_correlation: 0.0084 - val_loss: 1.5719 - val_mse: 0.1082 - val_correlation: 1.0316 - val_cross_correlation: -0.0052
# Epoch 55/500
# 13/13 [==============================] - ETA: 0s - loss: 1.5952 - mse: 0.1350 - correlation: 0.9726 - cross_correlation: 0.0092
# Epoch 55: val_loss improved from 1.57189 to 1.56438, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 534ms/step - loss: 1.5952 - mse: 0.1350 - correlation: 0.9726 - cross_correlation: 0.0092 - val_loss: 1.5644 - val_mse: 0.1082 - val_correlation: 1.0318 - val_cross_correlation: -0.0057
# Epoch 56/500
# 13/13 [==============================] - ETA: 0s - loss: 1.5876 - mse: 0.1348 - correlation: 0.9726 - cross_correlation: 0.0084
# Epoch 56: val_loss improved from 1.56438 to 1.55699, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 605ms/step - loss: 1.5876 - mse: 0.1348 - correlation: 0.9726 - cross_correlation: 0.0084 - val_loss: 1.5570 - val_mse: 0.1082 - val_correlation: 1.0325 - val_cross_correlation: -0.0062
# Epoch 57/500
# 13/13 [==============================] - ETA: 0s - loss: 1.5799 - mse: 0.1345 - correlation: 0.9712 - cross_correlation: 0.0102
# Epoch 57: val_loss improved from 1.55699 to 1.54952, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 536ms/step - loss: 1.5799 - mse: 0.1345 - correlation: 0.9712 - cross_correlation: 0.0102 - val_loss: 1.5495 - val_mse: 0.1081 - val_correlation: 1.0317 - val_cross_correlation: -0.0063
# Epoch 58/500
# 13/13 [==============================] - ETA: 0s - loss: 1.5725 - mse: 0.1345 - correlation: 0.9726 - cross_correlation: 0.0080
# Epoch 58: val_loss improved from 1.54952 to 1.54219, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 653ms/step - loss: 1.5725 - mse: 0.1345 - correlation: 0.9726 - cross_correlation: 0.0080 - val_loss: 1.5422 - val_mse: 0.1081 - val_correlation: 1.0325 - val_cross_correlation: -0.0069
# Epoch 59/500
# 13/13 [==============================] - ETA: 0s - loss: 1.5649 - mse: 0.1342 - correlation: 0.9701 - cross_correlation: 0.0099
# Epoch 59: val_loss improved from 1.54219 to 1.53492, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 9s 705ms/step - loss: 1.5649 - mse: 0.1342 - correlation: 0.9701 - cross_correlation: 0.0099 - val_loss: 1.5349 - val_mse: 0.1082 - val_correlation: 1.0337 - val_cross_correlation: -0.0076
# Epoch 60/500
# 13/13 [==============================] - ETA: 0s - loss: 1.5576 - mse: 0.1341 - correlation: 0.9707 - cross_correlation: 0.0097
# Epoch 60: val_loss improved from 1.53492 to 1.52772, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 587ms/step - loss: 1.5576 - mse: 0.1341 - correlation: 0.9707 - cross_correlation: 0.0097 - val_loss: 1.5277 - val_mse: 0.1082 - val_correlation: 1.0343 - val_cross_correlation: -0.0080
# Epoch 61/500
# 13/13 [==============================] - ETA: 0s - loss: 1.5501 - mse: 0.1339 - correlation: 0.9690 - cross_correlation: 0.0108
# Epoch 61: val_loss improved from 1.52772 to 1.52041, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 6s 469ms/step - loss: 1.5501 - mse: 0.1339 - correlation: 0.9690 - cross_correlation: 0.0108 - val_loss: 1.5204 - val_mse: 0.1081 - val_correlation: 1.0332 - val_cross_correlation: -0.0078
# Epoch 62/500
# 13/13 [==============================] - ETA: 0s - loss: 1.5426 - mse: 0.1337 - correlation: 0.9675 - cross_correlation: 0.0123
# Epoch 62: val_loss improved from 1.52041 to 1.51316, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 599ms/step - loss: 1.5426 - mse: 0.1337 - correlation: 0.9675 - cross_correlation: 0.0123 - val_loss: 1.5132 - val_mse: 0.1081 - val_correlation: 1.0324 - val_cross_correlation: -0.0077
# Epoch 63/500
# 13/13 [==============================] - ETA: 0s - loss: 1.5353 - mse: 0.1335 - correlation: 0.9668 - cross_correlation: 0.0125
# Epoch 63: val_loss improved from 1.51316 to 1.50602, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 7s 542ms/step - loss: 1.5353 - mse: 0.1335 - correlation: 0.9668 - cross_correlation: 0.0125 - val_loss: 1.5060 - val_mse: 0.1081 - val_correlation: 1.0333 - val_cross_correlation: -0.0082
# Epoch 64/500
# 13/13 [==============================] - ETA: 0s - loss: 1.5281 - mse: 0.1334 - correlation: 0.9673 - cross_correlation: 0.0109
# Epoch 64: val_loss improved from 1.50602 to 1.49897, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 13/13 [==============================] - 8s 603ms/step - loss: 1.5281 - mse: 0.1334 - correlation: 0.9673 - cross_correlation: 0.0109 - val_loss: 1.4990 - val_mse: 0.1082 - val_correlation: 1.0348 - val_cross_correlation: -0.0091
# Epoch 65/500
# 13/13 [==============================] - ETA: 0s - loss: 1.5208 - mse: 0.1332 - correlation: 0.9665 - cross_correlation: 0.0126
# Epoch 65: val_loss improved from 1.49897 to 1.49183, saving model to CV_results/model_crossval0-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# ...
# Epoch 37/500
# 14/14 [==============================] - ETA: 0s - loss: 1.7121 - mse: 0.1354 - correlation: 0.9698 - cross_correlation: 0.0189
# Epoch 37: val_loss improved from 1.70067 to 1.69194, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 407ms/step - loss: 1.7121 - mse: 0.1354 - correlation: 0.9698 - cross_correlation: 0.0189 - val_loss: 1.6919 - val_mse: 0.1200 - val_correlation: 1.0037 - val_cross_correlation: -0.0017
# Epoch 38/500
# 14/14 [==============================] - ETA: 0s - loss: 1.7031 - mse: 0.1350 - correlation: 0.9687 - cross_correlation: 0.0200
# Epoch 38: val_loss improved from 1.69194 to 1.68336, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 440ms/step - loss: 1.7031 - mse: 0.1350 - correlation: 0.9687 - cross_correlation: 0.0200 - val_loss: 1.6834 - val_mse: 0.1200 - val_correlation: 1.0034 - val_cross_correlation: -0.0016
# Epoch 39/500
# 14/14 [==============================] - ETA: 0s - loss: 1.6943 - mse: 0.1347 - correlation: 0.9692 - cross_correlation: 0.0192
# Epoch 39: val_loss improved from 1.68336 to 1.67447, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 416ms/step - loss: 1.6943 - mse: 0.1347 - correlation: 0.9692 - cross_correlation: 0.0192 - val_loss: 1.6745 - val_mse: 0.1197 - val_correlation: 1.0019 - val_cross_correlation: -0.0011
# Epoch 40/500
# 14/14 [==============================] - ETA: 0s - loss: 1.6854 - mse: 0.1344 - correlation: 0.9689 - cross_correlation: 0.0206
# Epoch 40: val_loss improved from 1.67447 to 1.66575, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 412ms/step - loss: 1.6854 - mse: 0.1344 - correlation: 0.9689 - cross_correlation: 0.0206 - val_loss: 1.6658 - val_mse: 0.1195 - val_correlation: 1.0008 - val_cross_correlation: -6.7575e-04
# Epoch 41/500
# 14/14 [==============================] - ETA: 0s - loss: 1.6765 - mse: 0.1341 - correlation: 0.9675 - cross_correlation: 0.0214
# Epoch 41: val_loss improved from 1.66575 to 1.65709, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 466ms/step - loss: 1.6765 - mse: 0.1341 - correlation: 0.9675 - cross_correlation: 0.0214 - val_loss: 1.6571 - val_mse: 0.1193 - val_correlation: 0.9992 - val_cross_correlation: -3.1861e-04
# Epoch 42/500
# 14/14 [==============================] - ETA: 0s - loss: 1.6678 - mse: 0.1338 - correlation: 0.9677 - cross_correlation: 0.0210
# Epoch 42: val_loss improved from 1.65709 to 1.64843, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 399ms/step - loss: 1.6678 - mse: 0.1338 - correlation: 0.9677 - cross_correlation: 0.0210 - val_loss: 1.6484 - val_mse: 0.1191 - val_correlation: 0.9984 - val_cross_correlation: 5.0159e-05
# Epoch 43/500
# 14/14 [==============================] - ETA: 0s - loss: 1.6588 - mse: 0.1332 - correlation: 0.9642 - cross_correlation: 0.0233
# Epoch 43: val_loss improved from 1.64843 to 1.63998, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 7s 478ms/step - loss: 1.6588 - mse: 0.1332 - correlation: 0.9642 - cross_correlation: 0.0233 - val_loss: 1.6400 - val_mse: 0.1190 - val_correlation: 0.9979 - val_cross_correlation: 1.8603e-04
# Epoch 44/500
# 14/14 [==============================] - ETA: 0s - loss: 1.6504 - mse: 0.1331 - correlation: 0.9648 - cross_correlation: 0.0235
# Epoch 44: val_loss improved from 1.63998 to 1.63159, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 62s 5s/step - loss: 1.6504 - mse: 0.1331 - correlation: 0.9648 - cross_correlation: 0.0235 - val_loss: 1.6316 - val_mse: 0.1190 - val_correlation: 0.9973 - val_cross_correlation: 3.6169e-04
# Epoch 45/500
# 14/14 [==============================] - ETA: 0s - loss: 1.6417 - mse: 0.1328 - correlation: 0.9635 - cross_correlation: 0.0248
# Epoch 45: val_loss improved from 1.63159 to 1.62322, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 410ms/step - loss: 1.6417 - mse: 0.1328 - correlation: 0.9635 - cross_correlation: 0.0248 - val_loss: 1.6232 - val_mse: 0.1189 - val_correlation: 0.9969 - val_cross_correlation: 4.7037e-04
# Epoch 46/500
# 14/14 [==============================] - ETA: 0s - loss: 1.6333 - mse: 0.1326 - correlation: 0.9641 - cross_correlation: 0.0236
# Epoch 46: val_loss improved from 1.62322 to 1.61489, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 414ms/step - loss: 1.6333 - mse: 0.1326 - correlation: 0.9641 - cross_correlation: 0.0236 - val_loss: 1.6149 - val_mse: 0.1188 - val_correlation: 0.9967 - val_cross_correlation: 4.4408e-04
# Epoch 47/500
# 14/14 [==============================] - ETA: 0s - loss: 1.6248 - mse: 0.1324 - correlation: 0.9625 - cross_correlation: 0.0241
# Epoch 47: val_loss improved from 1.61489 to 1.60648, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 408ms/step - loss: 1.6248 - mse: 0.1324 - correlation: 0.9625 - cross_correlation: 0.0241 - val_loss: 1.6065 - val_mse: 0.1186 - val_correlation: 0.9953 - val_cross_correlation: 6.5451e-04
# Epoch 48/500
# 14/14 [==============================] - ETA: 0s - loss: 1.6163 - mse: 0.1321 - correlation: 0.9621 - cross_correlation: 0.0252
# Epoch 48: val_loss improved from 1.60648 to 1.59831, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 448ms/step - loss: 1.6163 - mse: 0.1321 - correlation: 0.9621 - cross_correlation: 0.0252 - val_loss: 1.5983 - val_mse: 0.1186 - val_correlation: 0.9958 - val_cross_correlation: 5.8372e-04
# Epoch 49/500
# 14/14 [==============================] - ETA: 0s - loss: 1.6079 - mse: 0.1318 - correlation: 0.9605 - cross_correlation: 0.0274
# Epoch 49: val_loss improved from 1.59831 to 1.59006, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 429ms/step - loss: 1.6079 - mse: 0.1318 - correlation: 0.9605 - cross_correlation: 0.0274 - val_loss: 1.5901 - val_mse: 0.1185 - val_correlation: 0.9955 - val_cross_correlation: 7.5459e-04
# Epoch 50/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5997 - mse: 0.1316 - correlation: 0.9608 - cross_correlation: 0.0269
# Epoch 50: val_loss improved from 1.59006 to 1.58187, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 407ms/step - loss: 1.5997 - mse: 0.1316 - correlation: 0.9608 - cross_correlation: 0.0269 - val_loss: 1.5819 - val_mse: 0.1183 - val_correlation: 0.9954 - val_cross_correlation: 6.7548e-04
# Epoch 51/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5913 - mse: 0.1313 - correlation: 0.9596 - cross_correlation: 0.0278
# Epoch 51: val_loss improved from 1.58187 to 1.57373, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 456ms/step - loss: 1.5913 - mse: 0.1313 - correlation: 0.9596 - cross_correlation: 0.0278 - val_loss: 1.5737 - val_mse: 0.1182 - val_correlation: 0.9949 - val_cross_correlation: 7.5262e-04
# Epoch 52/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5831 - mse: 0.1312 - correlation: 0.9586 - cross_correlation: 0.0279
# Epoch 52: val_loss improved from 1.57373 to 1.56575, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 60s 5s/step - loss: 1.5831 - mse: 0.1312 - correlation: 0.9586 - cross_correlation: 0.0279 - val_loss: 1.5658 - val_mse: 0.1182 - val_correlation: 0.9952 - val_cross_correlation: 6.9685e-04
# Epoch 53/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5750 - mse: 0.1310 - correlation: 0.9600 - cross_correlation: 0.0283
# Epoch 53: val_loss improved from 1.56575 to 1.55785, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 464ms/step - loss: 1.5750 - mse: 0.1310 - correlation: 0.9600 - cross_correlation: 0.0283 - val_loss: 1.5579 - val_mse: 0.1183 - val_correlation: 0.9965 - val_cross_correlation: 5.3229e-04
# Epoch 54/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5668 - mse: 0.1307 - correlation: 0.9569 - cross_correlation: 0.0290
# Epoch 54: val_loss improved from 1.55785 to 1.54990, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 409ms/step - loss: 1.5668 - mse: 0.1307 - correlation: 0.9569 - cross_correlation: 0.0290 - val_loss: 1.5499 - val_mse: 0.1182 - val_correlation: 0.9964 - val_cross_correlation: 6.6336e-04
# Epoch 55/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5588 - mse: 0.1305 - correlation: 0.9566 - cross_correlation: 0.0308
# Epoch 55: val_loss improved from 1.54990 to 1.54199, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 440ms/step - loss: 1.5588 - mse: 0.1305 - correlation: 0.9566 - cross_correlation: 0.0308 - val_loss: 1.5420 - val_mse: 0.1181 - val_correlation: 0.9966 - val_cross_correlation: 9.0969e-04
# Epoch 56/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5507 - mse: 0.1303 - correlation: 0.9558 - cross_correlation: 0.0312
# Epoch 56: val_loss improved from 1.54199 to 1.53408, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 446ms/step - loss: 1.5507 - mse: 0.1303 - correlation: 0.9558 - cross_correlation: 0.0312 - val_loss: 1.5341 - val_mse: 0.1180 - val_correlation: 0.9972 - val_cross_correlation: 0.0012
# Epoch 57/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5428 - mse: 0.1302 - correlation: 0.9533 - cross_correlation: 0.0337
# Epoch 57: val_loss improved from 1.53408 to 1.52631, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 7s 493ms/step - loss: 1.5428 - mse: 0.1302 - correlation: 0.9533 - cross_correlation: 0.0337 - val_loss: 1.5263 - val_mse: 0.1180 - val_correlation: 0.9974 - val_cross_correlation: 0.0014
# Epoch 58/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5348 - mse: 0.1300 - correlation: 0.9532 - cross_correlation: 0.0335
# Epoch 58: val_loss improved from 1.52631 to 1.51857, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 5s 393ms/step - loss: 1.5348 - mse: 0.1300 - correlation: 0.9532 - cross_correlation: 0.0335 - val_loss: 1.5186 - val_mse: 0.1180 - val_correlation: 0.9971 - val_cross_correlation: 0.0014
# Epoch 59/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5269 - mse: 0.1297 - correlation: 0.9505 - cross_correlation: 0.0356
# Epoch 59: val_loss improved from 1.51857 to 1.51086, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 433ms/step - loss: 1.5269 - mse: 0.1297 - correlation: 0.9505 - cross_correlation: 0.0356 - val_loss: 1.5109 - val_mse: 0.1180 - val_correlation: 0.9979 - val_cross_correlation: 0.0017
# Epoch 60/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5191 - mse: 0.1296 - correlation: 0.9507 - cross_correlation: 0.0357
# Epoch 60: val_loss improved from 1.51086 to 1.50331, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 906s 70s/step - loss: 1.5191 - mse: 0.1296 - correlation: 0.9507 - cross_correlation: 0.0357 - val_loss: 1.5033 - val_mse: 0.1181 - val_correlation: 0.9990 - val_cross_correlation: 0.0017
# Epoch 61/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5113 - mse: 0.1294 - correlation: 0.9482 - cross_correlation: 0.0372
# Epoch 61: val_loss improved from 1.50331 to 1.49572, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 413ms/step - loss: 1.5113 - mse: 0.1294 - correlation: 0.9482 - cross_correlation: 0.0372 - val_loss: 1.4957 - val_mse: 0.1181 - val_correlation: 0.9987 - val_cross_correlation: 0.0019
# Epoch 62/500
# 14/14 [==============================] - ETA: 0s - loss: 1.5036 - mse: 0.1293 - correlation: 0.9473 - cross_correlation: 0.0380
# Epoch 62: val_loss improved from 1.49572 to 1.48807, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 416ms/step - loss: 1.5036 - mse: 0.1293 - correlation: 0.9473 - cross_correlation: 0.0380 - val_loss: 1.4881 - val_mse: 0.1180 - val_correlation: 0.9986 - val_cross_correlation: 0.0023
# Epoch 63/500
# 14/14 [==============================] - ETA: 0s - loss: 1.4958 - mse: 0.1291 - correlation: 0.9465 - cross_correlation: 0.0387
# Epoch 63: val_loss improved from 1.48807 to 1.48051, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 6s 459ms/step - loss: 1.4958 - mse: 0.1291 - correlation: 0.9465 - cross_correlation: 0.0387 - val_loss: 1.4805 - val_mse: 0.1179 - val_correlation: 0.9983 - val_cross_correlation: 0.0028
# Epoch 64/500
# 14/14 [==============================] - ETA: 0s - loss: 1.4882 - mse: 0.1290 - correlation: 0.9455 - cross_correlation: 0.0394
# Epoch 64: val_loss improved from 1.48051 to 1.47291, saving model to CV_results/model_crossval1-size8-input1024-lr0.004878689057515219-kernel27-reg0.006032564292289038-dropout0.8804727366138194.h5
# 14/14 [==============================] - 42845s 3296s/step - loss: 1.4882 - mse: 0.1290 - correlation: 0.9455 - cross_correlation: 0.0394 - val_loss: 1.4729 - val_mse: 0.1178 - val_correlation: 0.9975 - val_cross_correlation: 0.0034
# Epoch 65/500

# %%
print("Average MSE performance across folds:", np.mean(results_mse))
print("Average CORR performance across folds:", np.mean(results_corr))
print("Average CC performance across folds:", np.mean(results_cc))
# Out:
# Average MSE performance across folds: 0.12231316715478897
# Average CORR performance across folds: 0.9378519415855407
# Average CC performance across folds: 0.0539246825966984

# %%
# check visually
def plot_signals_in_grid(predicted_signals, true_signals, labels=['Predicted', 'True']):
    fig, axs = plt.subplots(len(predicted_signals)//2, 2, figsize=(20, 50))
    axs = axs.flatten() 

    for i in range(len(predicted_signals)):  
        ax = axs[i]
        pred_signal = predicted_signals[i]
        true_signal = true_signals[i]

        # Plotting both signals in the same subplot
        ax.plot(pred_signal, label=labels[0])
        ax.plot(true_signal, label=labels[1], alpha=0.75)
        ax.legend()
        ax.set_title(f'Example {i+1}')
    
    plt.tight_layout()
    plt.show()

# %%
results_cc
# Out:
# [-0.005258073098957539,
#  0.03349137678742409,
#  0.008275619708001614,
#  -0.009416820481419563,
#  0.108854278922081]
